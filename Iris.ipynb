# %% [markdown]
# <a href="https://colab.research.google.com/github/Manith-Ratnayake/UCI_machine_learning/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

X = iris.data.features
y = iris.data.targets

# %%
# concatenate dataset
iris_df = pd.concat([X, y], axis=1)
print(iris_df.head())
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
X.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
X.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# dtype: int64

# %%
X.value_counts()
# Out:
# sepal length  sepal width  petal length  petal width
# 4.9           3.1          1.5           0.1            3
# 5.8           2.7          5.1           1.9            2
#               4.0          1.2           0.2            1
# 5.9           3.0          4.2           1.5            1
# 6.2           3.4          5.4           2.3            1
#                                                        ..
# 5.5           2.3          4.0           1.3            1
#               2.4          3.7           1.0            1
#                            3.8           1.1            1
#               2.5          4.0           1.3            1
# 7.9           3.8          6.4           2.0            1
# Name: count, Length: 147, dtype: int64

# %%
y['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
X["sepal width"].hist()
# Out:
# <Axes: >

# %%
X["sepal length"].hist()
# Out:
# <Axes: >

# %%
X["petal length"].hist()
# Out:
# <Axes: >

# %%
X["petal width"].hist()
# Out:
# <Axes: >

# %%
colors = ["orange", "blue", "grey"]
species_in_dataset = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
len(species_in_dataset)
# Out:
# 3

# %%
for i in range(len(species_in_dataset)):

    # Filter data for the current species
    species_data = iris_df[iris_df["class"] == species_in_dataset[i]]

    # Scatter plot for the current species
    plt.scatter(species_data['sepal length'], species_data['sepal width'],
                c=colors[i], label=species_in_dataset[i])


plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()
plt.title("Sepal Length vs Sepal Width by Species")
plt.show()

# %%
for i in range(len(species_in_dataset)):

    # Filter data for the current species
    species_data = iris_df[iris_df["class"] == species_in_dataset[i]]

    # Scatter plot for the current species
    plt.scatter(species_data['petal length'], species_data['petal width'],
                c=colors[i], label=species_in_dataset[i])


plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.legend()
plt.title("Sepal Length vs Sepal Width by Species")
plt.show()

# %%
for i in range(len(species_in_dataset)):

    # Filter data for the current species
    species_data = iris_df[iris_df["class"] == species_in_dataset[i]]

    # Scatter plot for the current species
    plt.scatter(species_data['petal length'], species_data['sepal length'],
                c=colors[i], label=species_in_dataset[i])


plt.xlabel("Petal Length (cm)")
plt.ylabel("Sepal Length (cm)")
plt.legend()
plt.title("Sepal Length vs Sepal Width by Species")
plt.show()

# %%
for i in range(len(species_in_dataset)):

    # Filter data for the current species
    species_data = iris_df[iris_df["class"] == species_in_dataset[i]]

    # Scatter plot for the current species
    plt.scatter(species_data['petal width'], species_data['sepal width'],
                c=colors[i], label=species_in_dataset[i])


plt.xlabel("Petal Width (cm)")
plt.ylabel("Sepal Widtj (cm)")
plt.legend()
plt.title("Sepal Length vs Sepal Width by Species")
plt.show()

# %%
X.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
corr = X.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
iris_df["class"] = le.fit_transform(iris_df["class"])
iris_df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  class
# 0           5.1          3.5           1.4          0.2      0
# 1           4.9          3.0           1.4          0.2      0
# 2           4.7          3.2           1.3          0.2      0
# 3           4.6          3.1           1.5          0.2      0
# 4           5.0          3.6           1.4          0.2      0

# %%
# Train = 70%  test = 30%

from sklearn.model_selection import train_test_split
X = iris_df.drop(columns=["class"])
y = iris_df["class"]
X_train, X_test, y_train, y_test, = train_test_split(X,y, test_size = 0.30)

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
print("Accuracy : ", model.score(X_test, y_test) *  100)
# Out:
# Accuracy :  95.55555555555556

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=200)
model.fit(X_train,y_train)
print("Accuracy : ", model.score(X_test, y_test) * 100)
# Out:
# Accuracy :  95.55555555555556

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print("Accracy : ", model.score(X_test, y_test) * 100)
# Out:
# Accracy :  97.77777777777777

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report


rf_model = RandomForestClassifier(n_estimators=100, random_state=42)


rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.96
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.94      0.94      0.94        17
#            2       0.94      0.94      0.94        16
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45
